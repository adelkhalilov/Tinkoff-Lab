# %% [markdown]
# ## Привет
#
# * Тебе предлагается выбрать первую или вторую задачку для решения :)
#
# * Да, можно выбрать и две
#
# * Да, можно решить и бонусную - третью ⛳
#
# **Оформление решения**
#
# colab-notebook, который запускается (или готовый python script)
#
# можно использовать публичный git репозиторий для хранения кода при необходимости (например на github)
#
#
# **Комментарий**
#
# * В первую очередь будем смотреть на умение разбираться в постановке задачи и писать свой код
#
# * Да, можно пытаться адаптировать какие-то решения
#
# * Тут нет больших датасетов и огромных требований к качеству по метрикам
#
# * Важно скорее предложить релевантную идею и реализовать ее
#
# * Язык python - фреймворки torch и tf (лучше на торче, если не составит дополнительного труда)

# %% [markdown]
# ## Идентификация спикеров (задача 1)
#
# ![im1.jpeg](data:image/jpeg;base64,...)
#
#
# **Цель:**
#
# * Поработать с аудио сигналами
# * Показать умение строить и обучать простые модели
#
# **Условие:**
#
# Решить задачу идентификация спикеров по голосу (определения личности говорящего)
#
# **Данные**
#
# В качестве датасета предлагается использовать [VCC2018](https://datashare.ed.ac.uk/handle/10283/3061?show=full)
#
#  В данном датасете всего 8 спикеров: 4 мужчины и 4 женщины
#
# * Для обучения предлагается использовать аудиозаписи из vcc2018_training\VCC2S*
#
# * Для тестирования - из vcc2018_evaluation\*

# %% [markdown]
# ##  Решение

# %% [markdown]
# **Скачайте вспомогательный файл для скачивания данных с google drive**
#
# https://github.com/adelkhalilov/Tinkoff-Lab/blob/main/gfile.py

# %% [markdown]
# ####  Все следующие ячейки запускать без изменений, все файлы должны быть доступны для скачиваний

# %%
#!L
# import zipfile
import os    
from os import walk
import time
from google.colab import drive
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
import numpy as np
# plt.rcParams.update({'axes.titlesize': 'small'})

import torch, torch.nn as nn

import librosa

from gfile import download_list

device = torch.device('cuda:0')
use_cuda = torch.cuda.is_available()

print("Torch version:", torch.__version__)
if use_cuda:
    print("Using GPU")
else:
    print("Not using GPU")
# Out:
# Torch version: 1.10.0+cu111
# Using GPU

# %% [markdown]
# ##**Скачивание данных**

# %%
download_list(
    url='https://drive.google.com/file/d/1r139_Kn2Rij9_0p2wnEp8UZMJKcXMLdu/view?usp=sharing',
    filename='vcc2018_database_training.zip',
    target_dir='.'
)

# !unzip 'vcc2018_database_training.zip'
# Out:
# It took  1.45sec to download 117.1 MB vcc2018_database_training.zip
# Archive:  vcc2018_database_training.zip
#    creating: vcc2018_training/
#    creating: vcc2018_training/VCC2SF3/
#   inflating: vcc2018_training/VCC2SF3/20068.wav
#   inflating: vcc2018_training/VCC2SF3/20031.wav
#   inflating: vcc2018_training/VCC2SF3/20039.wav
#   inflating: vcc2018_training/VCC2SF3/20021.wav
#   inflating: vcc2018_training/VCC2SF3/20060.wav
#   inflating: vcc2018_training/VCC2SF3/20005.wav
#   inflating: vcc2018_training/VCC2SF3/20003.wav
#   inflating: vcc2018_training/VCC2SF3/20010.wav
#   inflating: vcc2018_training/VCC2SF3/20044.wav
#   inflating: vcc2018_training/VCC2SF3/20026.wav
#   inflating: vcc2018_training/VCC2SF3/20040.wav
#   inflating: vcc2018_training/VCC2TF2/10031.wav
#   inflating: vcc2018_training/VCC2TF2/10028.wav
#   inflating: vcc2018_training/VCC2TF2/10033.wav
#    creating: vcc2018_training/Transcriptions/
#    creating: vcc2018_training/Transcriptions/HUB/
#  extracting: vcc2018_training/Transcriptions/HUB/10029.txt
#   inflating: vcc2018_training/Transcriptions/HUB/10053.txt
#  extracting: vcc2018_training/Transcriptions/HUB/10043.txt
#   inflating: vcc2018_training/Transcriptions/HUB/10079.txt
#  extracting: vcc2018_training/Transcriptions/HUB/10033.txt
#   inflating: vcc2018_training/Transcriptions/HUB/10046.txt
#   inflating: vcc2018_training/Transcriptions/HUB/10054.txt
#  extracting: vcc2018_training/Transcriptions/HUB/10057.txt
#  extracting: vcc2018_training/Transcriptions/HUB/10075.txt
#   inflating: vcc2018_training/Transcriptions/HUB/10040.txt
#   inflating: vcc2018_training/Transcriptions/HUB/10010.txt
#  extracting: vcc2018_training/Transcriptions/HUB/10008.txt
#   inflating: vcc2018_training/Transcriptions/HUB/10012.txt
#  extracting: vcc2018_training/Transcriptions/HUB/10018.txt
#   inflating: vcc2018_training/Transcriptions/HUB/10003.txt
#  extracting: vcc2018_training/Transcriptions/HUB/10026.txt
#   inflating: vcc2018_training/Transcriptions/HUB/10006.txt
#  extracting: vcc2018_training/Transcriptions/HUB/10038.txt
#  extracting: vcc2018_training/Transcriptions/HUB/10016.txt
#   inflating: vcc2018_training/Transcriptions/HUB/10058.txt
#   inflating: vcc2018_training/Transcriptions/HUB/10034.txt
#  extracting: vcc2018_training/Transcriptions/HUB/10072.txt
#   inflating: vcc2018_training/Transcriptions/HUB/10031.txt
#  extracting: vcc2018_training/Transcriptions/HUB/10025.txt
#   inflating: vcc2018_training/Transcriptions/HUB/10001.txt
#   inflating: vcc2018_training/Transcriptions/HUB/10069.txt
#  extracting: vcc2018_training/Transcriptions/HUB/10048.txt
#   inflating: vcc2018_training/Transcriptions/HUB/10044.txt
#   inflating: vcc2018_training/Transcriptions/HUB/10041.txt
#  extracting: vcc2018_training/Transcriptions/HUB/10049.txt
#  extracting: vcc2018_training/Transcriptions/HUB/10060.txt
#   inflating: vcc2018_training/Transcriptions/HUB/10059.txt
#   inflating: vcc2018_training/Transcriptions/HUB/10070.txt
#  extracting: vcc2018_training/Transcriptions/HUB/10065.txt
#  extracting: vcc2018_training/Transcriptions/HUB/10062.txt
#   inflating: vcc2018_training/Transcriptions/HUB/10076.txt
#   inflating: vcc2018_training/Transcriptions/HUB/10078.txt
#   inflating: vcc2018_training/Transcriptions/HUB/10045.txt
#   inflating: vcc2018_training/Transcriptions/HUB/10014.txt
#   inflating: vcc2018_training/Transcriptions/HUB/10011.txt
#   inflating: vcc2018_training/Transcriptions/HUB/10023.txt
#  extracting: vcc2018_training/Transcriptions/HUB/10009.txt
#   inflating: vcc2018_training/Transcriptions/HUB/10074.txt
#   inflating: vcc2018_training/Transcriptions/HUB/10039.txt
#  extracting: vcc2018_training/Transcriptions/HUB/10022.txt
#   inflating: vcc2018_training/Transcriptions/HUB/10052.txt
#   inflating: vcc2018_training/Transcriptions/HUB/10027.txt
#   inflating: vcc2018_training/Transcriptions/HUB/10007.txt
#  extracting: vcc2018_training/Transcriptions/HUB/10035.txt
#  extracting: vcc2018_training/Transcriptions/HUB/10055.txt
#  extracting: vcc2018_training/Transcriptions/HUB/10021.txt
#   inflating: vcc2018_training/Transcriptions/HUB/10015.txt
#   inflating: vcc2018_training/Transcriptions/HUB/10073.txt
#   inflating: vcc2018_training/Transcriptions/HUB/10037.txt
#   inflating: vcc2018_training/Transcriptions/HUB/10071.txt
#   inflating: vcc2018_training/Transcriptions/HUB/10068.txt
#  extracting: vcc2018_training/Transcriptions/HUB/10019.txt
#   inflating: vcc2018_training/Transcriptions/HUB/10066.txt
#  extracting: vcc2018_training/Transcriptions/HUB/10064.txt
#  extracting: vcc2018_training/Transcriptions/HUB/10051.txt
#  extracting: vcc2018_training/Transcriptions/HUB/10061.txt
#  extracting: vcc2018_training/Transcriptions/HUB/10050.txt
#  extracting: vcc2018_training/Transcriptions/HUB/10080.txt
#   inflating: vcc2018_training/Transcriptions/HUB/10036.txt
#   inflating: vcc2018_training/Transcriptions/HUB/10067.txt
#   inflating: vcc2018_training/Transcriptions/HUB/10030.txt
#  extracting: vcc2018_training/Transcriptions/HUB/10077.txt
#  extracting: vcc2018_training/Transcriptions/HUB/10020.txt
#   inflating: vcc2018_training/Transcriptions/HUB/10028.txt
#   inflating: vcc2018_training/Transcriptions/HUB/10017.txt
#  extracting: vcc2018_training/Transcriptions/HUB/10004.txt
#  extracting: vcc2018_training/Transcriptions/HUB/10081.txt
#   inflating: vcc2018_training/Transcriptions/HUB/10002.txt
#  extracting: vcc2018_training/Transcriptions/HUB/10013.txt
#   inflating: vcc2018_training/Transcriptions/HUB/10024.txt
#   inflating: vcc2018_training/Transcriptions/HUB/10032.txt
#  extracting: vcc2018_training/Transcriptions/HUB/10005.txt
#  extracting: vcc2018_training/Transcriptions/HUB/10042.txt
#   inflating: vcc2018_training/Transcriptions/HUB/10063.txt
#   inflating: vcc2018_training/Transcriptions/HUB/10047.txt
#   inflating: vcc2018_training/Transcriptions/HUB/10056.txt
#    creating: vcc2018_training/Transcriptions/SPOKE/
#  extracting: vcc2018_training/Transcriptions/SPOKE/20073.txt
#   inflating: vcc2018_training/Transcriptions/SPOKE/20036.txt
#   inflating: vcc2018_training/Transcriptions/SPOKE/20022.txt
#  extracting: vcc2018_training/Transcriptions/SPOKE/20028.txt
#   inflating: vcc2018_training/Transcriptions/SPOKE/20002.txt
#  extracting: vcc2018_training/Transcriptions/SPOKE/20027.txt
#   inflating: vcc2018_training/Transcriptions/SPOKE/20025.txt
#  extracting: vcc2018_training/Transcriptions/SPOKE/20038.txt
#  extracting: vcc2018_training/Transcriptions/SPOKE/20018.txt
#   inflating: vcc2018_training/Transcriptions/SPOKE/20039.txt
#   inflating: vcc2018_training/Transcriptions/SPOKE/20058.txt
#   inflating: vcc2018_training/Transcriptions/SPOKE/20008.txt
#  extracting: vcc2018_training/Transcriptions/SPOKE/20052.txt
#  extracting: vcc2018_training/Transcriptions/SPOKE/20077.txt
#   inflating: vcc2018_evaluation/VCC2SM4/30025.wav
#   inflating: vcc2018_evaluation/README.txt
#    creating: vcc2018_evaluation/VCC2SF4/
#   inflating: vcc2018_evaluation/VCC2SF4/30023.wav
#   inflating: vcc2018_evaluation/VCC2SF4/30011.wav
#   inflating: vcc2018_evaluation/VCC2SF4/30005.wav
#   inflating: vcc2018_evaluation/VCC2SF4/30008.wav
#   inflating: vcc2018_evaluation/VCC2SF4/30014.wav
#   inflating: vcc2018_evaluation/VCC2SF4/30027.wav
#   inflating: vcc2018_evaluation/VCC2SF4/30004.wav
#   inflating: vcc2018_evaluation/VCC2SF4/30012.wav
#   inflating: vcc2018_evaluation/VCC2SF4/30018.wav
#   inflating: vcc2018_evaluation/VCC2SF4/30026.wav
#   inflating: vcc2018_evaluation/VCC2SF4/30020.wav
#   inflating: vcc2018_evaluation/VCC2SF4/30032.wav
#   inflating: vcc2018_evaluation/VCC2SF4/30009.wav
#   inflating: vcc2018_evaluation/VCC2SF4/30031.wav
#   inflating: vcc2018_evaluation/VCC2SF4/30007.wav
#   inflating: vcc2018_evaluation/VCC2SF4/30013.wav
#   inflating: vcc2018_evaluation/VCC2SF4/30016.wav
#   inflating: vcc2018_evaluation/VCC2SF4/30030.wav
#   inflating: vcc2018_evaluation/VCC2SF4/30024.wav
#   inflating: vcc2018_evaluation/VCC2SF4/30034.wav
#   inflating: vcc2018_evaluation/VCC2SF4/30015.wav
#   inflating: vcc2018_evaluation/VCC2SF4/30021.wav
#   inflating: vcc2018_evaluation/VCC2SF4/30028.wav
#   inflating: vcc2018_evaluation/VCC2SF4/30029.wav
#   inflating: vcc2018_evaluation/VCC2SF4/30006.wav
#   inflating: vcc2018_evaluation/VCC2SF4/30003.wav
#   inflating: vcc2018_evaluation/VCC2SF4/30019.wav
#   inflating: vcc2018_evaluation/VCC2SF4/30010.wav
#   inflating: vcc2018_evaluation/VCC2SF4/30035.wav
#   inflating: vcc2018_evaluation/VCC2SF4/30017.wav
#   inflating: vcc2018_evaluation/VCC2SF4/30022.wav
#   inflating: vcc2018_evaluation/VCC2SF4/30033.wav
#   inflating: vcc2018_evaluation/VCC2SF4/30001.wav
#   inflating: vcc2018_evaluation/VCC2SF4/30002.wav
#   inflating: vcc2018_evaluation/VCC2SF4/30025.wav

# %% [markdown]
# ## **Подготовка данных**
#
#
# #### Данные скачаны, но в исходном датасете все аудиодорожки лежат по отдельным папкам для каждого спикера. Объединим все директории в train и evaluation частях в единственные директории `vcc2018_training/train` и `vcc2018_evaluation/evaluation` соответственно

# %%
directory = "train"

# Parent Directory path
parent_dir = "./vcc2018_training"

# Path
path_train = os.path.join(parent_dir, directory)

os.mkdir(path_train)

# %%
directory = "evaluation"

parent_dir = "./vcc2018_evaluation"

path_evaluation = os.path.join(parent_dir, directory)

os.mkdir(path_evaluation)

# %% [markdown]
# Мы будем предсказывать в качестве метки числа от $0$ до $7$, соотвествующие спикерам из датасета согласно словарю `labels_to_name_mapping`

# %%
labels_to_name_mapping = {
    0 : 'F1', 
    1 : 'F2', 
    2 : 'F3', 
    3 : 'F4', 
    4 : 'M1',
    5 : 'M2',
    6 : 'M3',
    7 : 'M4',
}

# %%
names_to_label_mapping = {val: key for key, val in labels_to_name_mapping.items()}
names_to_label_mapping
# Out:
# {'F1': 0, 'F2': 1, 'F3': 2, 'F4': 3, 'M1': 4, 'M2': 5, 'M3': 6, 'M4': 7}

# %% [markdown]
# Скопируем все аудиозаписи в одну папку и добавим в имена аудиофайлов в начало по цифре обозначающей метку спикера

# %%
import shutil
from shutil import copy

for name_suff in names_to_label_mapping :
    parent_dir = "./vcc2018_training/VCC2S" + name_suff

    cnt = 0
    for f in os.listdir(parent_dir) : 
        if os.path.isfile(os.path.join(parent_dir, f)) :
            new_filename =  str(names_to_label_mapping[name_suff]) + '_' + f
            copy(os.path.join(parent_dir, f), os.path.join(path_train, new_filename)) 
            cnt += 1
    print(cnt)
# Out:
# 81
# 81
# 81
# 81
# 81
# 81
# 81
# 81

# %%
for name_suff in names_to_label_mapping :
    parent_dir = "./vcc2018_evaluation/VCC2S" + name_suff

    cnt = 0
    for f in os.listdir(parent_dir) : 
        if os.path.isfile(os.path.join(parent_dir, f)) :
            new_filename =  str(names_to_label_mapping[name_suff]) + '_' + f
            copy(os.path.join(parent_dir, f), os.path.join(path_evaluation, new_filename)) 
            cnt += 1
    print(cnt)
# Out:
# 35
# 35
# 35
# 35
# 35
# 35
# 35
# 35

# %% [markdown]
# ##  **Предобработка данных. Извлечение фичей из аудиозаписей**

# %%
#list the files
filelist = os.listdir(path_train) 
#read them into pandas
train_df = pd.DataFrame(filelist)

# %%
train_df
# Out:
#                0
# 0    7_20053.wav
# 1    1_10040.wav
# 2    4_10031.wav
# 3    4_10003.wav
# 4    7_20057.wav
# ..           ...
# 643  1_10074.wav
# 644  5_10079.wav
# 645  5_10014.wav
# 646  3_20006.wav
# 647  7_20035.wav
#
# [648 rows x 1 columns]

# %% [markdown]
# Как видно названия файлов первым символом содержат label спикера

# %%
train_df = train_df.sort_values(by=[0])
train_df
# Out:
#                0
# 290  0_10001.wav
# 520  0_10002.wav
# 311  0_10003.wav
# 86   0_10004.wav
# 14   0_10005.wav
# ..           ...
# 143  7_20077.wav
# 89   7_20078.wav
# 226  7_20079.wav
# 592  7_20080.wav
# 281  7_20081.wav
#
# [648 rows x 1 columns]

# %%
train_df.index = np.arange(0, len(train_df))
train_df
# Out:
#                0
# 0    7_20053.wav
# 1    1_10040.wav
# 2    4_10031.wav
# 3    4_10003.wav
# 4    7_20057.wav
# ..           ...
# 643  1_10074.wav
# 644  5_10079.wav
# 645  5_10014.wav
# 646  3_20006.wav
# 647  7_20035.wav
#
# [648 rows x 1 columns]

# %%
train_df = train_df.rename(columns={0:'file'})

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 648 entries, 0 to 647
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   file    648 non-null    object
# dtypes: object(1)
# memory usage: 10.1+ KB

# %% [markdown]
# Создадим колонку со значением метки

# %%
# We now assign the speaker to a new column 
train_df['speaker'] = train_df['file'].apply(lambda x : int(x[0]))

# %%
labels_train = np.array(train_df['speaker'])
labels_train
# Out:
# array([7, 1, 4, 4, 7, 1, 0, 0, 3, 1, 0, 2, 1, 0, 0, 6, 2, 2, 2, 0, 5, 3,
#        6, 1, 4, 6, 4, 3, 6, 0, 4, 2, 2, 7, 5, 6, 3, 0, 7, 1, 6, 2, 1, 2,
#        5, 1, 2, 7, 6, 5, 2, 7, 0, 1, 5, 1, 6, 3, 7, 5, 4, 7, 4, 2, 3, 4,
#        3, 4, 6, 4, 2, 6, 6, 0, 0, 3, 1, 3, 6, 7, 7, 0, 7, 6, 4, 4, 0, 4,
#        2, 7, 7, 7, 6, 5, 7, 3, 2, 2, 0, 6, 2, 5, 0, 4, 5, 0, 3, 6, 3, 0,
#        3, 3, 4, 3, 1, 3, 7, 7, 4, 3, 2, 7, 6, 4, 0, 7, 6, 2, 5, 1, 4, 7,
#        5, 5, 1, 3, 0, 6, 0, 7, 2, 3, 6, 7, 1, 5, 3, 4, 2, 2, 1, 0, 6, 6,
#        1, 4, 0, 2, 7, 2, 5, 7, 4, 6, 5, 0, 5, 3, 3, 6, 6, 6, 1, 4, 2, 3,
#        2, 1, 0, 1, 6, 7, 4, 1, 2, 4, 2, 3, 0, 0, 4, 6, 3, 0, 3, 7, 0, 4,
#        5, 4, 0, 2, 1, 5, 5, 0, 6, 3, 4, 0, 6, 4, 3, 7, 3, 6, 5, 1, 3, 1,
#        4, 7, 6, 5, 5, 4, 7, 2, 6, 0, 4, 2, 0, 7, 6, 5, 2, 6, 5, 0, 3, 0,
#        1, 0, 3, 5, 3, 6, 2, 5, 7, 3, 5, 3, 4, 1, 7, 6, 6, 5, 2, 3, 5, 4,
#        2, 7, 1, 5, 2, 4, 5, 2, 4, 1, 3, 7, 0, 2, 3, 6, 1, 7, 3, 4, 5, 2,
#        7, 1, 1, 4, 0, 0, 2, 7, 7, 7, 3, 7, 6, 3, 7, 6, 1, 7, 3, 6, 6, 0,
#        0, 4, 3, 0, 7, 3, 2, 2, 0, 1, 7, 4, 7, 5, 7, 7, 5, 6, 3, 5, 2, 1,
#        0, 4, 5, 7, 2, 6, 0, 7, 1, 6, 5, 2, 0, 5, 0, 7, 4, 0, 7, 5, 4, 6,
#        4, 3, 1, 0, 7, 7, 4, 4, 0, 0, 5, 6, 4, 4, 4, 7, 5, 4, 2, 1, 2, 1,
#        3, 7, 2, 2, 4, 5, 5, 3, 2, 5, 7, 5, 0, 0, 6, 7, 7, 7, 0, 3, 6, 6,
#        6, 3, 5, 2, 6, 1, 2, 7, 4, 7, 5, 6, 0, 7, 2, 2, 7, 1, 2, 3, 1, 6,
#        0, 1, 4, 0, 0, 4, 2, 5, 1, 6, 6, 1, 2, 1, 4, 1, 1, 5, 6, 4, 0, 3,
#        4, 5, 6, 4, 4, 4, 1, 2, 1, 7, 6, 2, 6, 2, 1, 1, 2, 6, 1, 6, 7, 4,
#        0, 2, 3, 4, 0, 0, 1, 7, 6, 3, 3, 1, 4, 6, 7, 1, 4, 0, 5, 1, 3, 1,
#        3, 6, 5, 6, 1, 0, 7, 2, 0, 6, 5, 2, 1, 3, 6, 5, 3, 4, 1, 7, 0, 4,
#        1, 3, 4, 3, 3, 3, 5, 3, 5, 3, 4, 1, 5, 0, 0, 3, 5, 5, 7, 2, 2, 3,
#        2, 5, 6, 0, 6, 6, 0, 4, 0, 1, 0, 2, 3, 1, 3, 1, 0, 7, 4, 2, 6, 4,
#        1, 2, 1, 3, 0, 4, 1, 5, 4, 0, 7, 4, 7, 5, 6, 1, 1, 1, 2, 2, 2, 1,
#        2, 5, 7, 6, 3, 5, 4, 6, 1, 0, 2, 2, 7, 5, 4, 5, 6, 2, 1, 3, 7, 5,
#        2, 4, 5, 7, 5, 0, 2, 5, 5, 3, 5, 1, 0, 7, 5, 4, 3, 3, 5, 6, 6, 1,
#        5, 3, 3, 4, 3, 4, 0, 1, 6, 3, 5, 6, 7, 2, 1, 2, 2, 5, 5, 7, 1, 0,
#        1, 5, 0, 4, 3, 1, 5, 5, 3, 7])

# %%
data_path = './vcc2018_training/train/'

# %% [markdown]
# Извлечем фичи из аудиофайлов с помощью библиотеки `librosa`

# %%
def extract_features(files):

# Sets the name to be the path to where the file is in my computer
    file_name = os.path.join(os.path.abspath(data_path), str(files.file))
# Loads the audio file as a floating point time series and assigns the default sample rate
# Sample rate is set to 22050 by default
    X, sample_rate = librosa.load(file_name, res_type='kaiser_fast')

# Generate Mel-frequency cepstral coefficients (MFCCs) from a time series 
    mfccs = np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T,axis=0)
# Generates a Short-time Fourier transform (STFT) to use in the chroma_stft
    stft = np.abs(librosa.stft(X))
# Computes a chromagram from a waveform or power spectrogram.
    chroma = np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T,axis=0)
# Computes a mel-scaled spectrogram.
    mel = np.mean(librosa.feature.melspectrogram(X, sr=sample_rate).T,axis=0)
# Computes spectral contrast
    contrast = np.mean(librosa.feature.spectral_contrast(S=stft, sr=sample_rate).T,axis=0)
# Computes the tonal centroid features (tonnetz)
    tonnetz = np.mean(librosa.feature.tonnetz(y=librosa.effects.harmonic(X), sr=sample_rate).T,axis=0)

    return mfccs, chroma, mel, contrast, tonnetz

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
train_features = train_df.apply(extract_features, axis=1)

# %%
train_features
# Out:
# 0      ([-378.03592, 92.72666, 19.311829, 40.690823, ...
# 1      ([-355.38324, 97.312256, -1.6822536, 19.359892...
# 2      ([-363.15662, 146.04207, -9.19652, 11.103923, ...
# 3      ([-290.01202, 129.31093, 5.444868, 17.88983, 2...
# 4      ([-336.6351, 98.35395, 19.41707, 33.25374, 18....
#                              ...
# 643    ([-391.9403, 96.753685, 11.220611, 25.019281, ...
# 644    ([-287.58667, 112.16736, -12.524475, 27.863607...
# 645    ([-304.8451, 93.43994, -7.360517, 21.463722, 3...
# 646    ([-238.91321, 133.77112, -39.52861, 14.875191,...
# 647    ([-340.2777, 103.581245, 15.970602, 40.119423,...
# Length: 648, dtype: object

# %%
summ = 0
for i in range(len(train_features[0])) : 
    print(train_features[0][i].shape)
    summ += len(train_features[0][i])
summ
# Out:
# (40,)
# (12,)
# (128,)
# (7,)
# (6,)
# 193

# %% [markdown]
# Для каждой строки (объекта выборки) объединим все получившиеся массивы в один

# %%
train_features_joined = []
for i in range(0, len(train_features)):
    train_features_joined.append(np.concatenate((
        train_features[i][0],
        train_features[i][1], 
        train_features[i][2], 
        train_features[i][3],
        train_features[i][4]), axis=0))

# %%
X_train = np.array(train_features_joined)
X_train
# Out:
# array([[-3.78035919e+02,  9.27266617e+01,  1.93118286e+01, ...,
#          2.60107652e-03,  7.12884116e-03,  4.20810976e-03],
#        [-3.55383240e+02,  9.73122559e+01, -1.68225360e+00, ...,
#          1.89317476e-02, -1.26354065e-02,  4.55404439e-03],
#        [-3.63156616e+02,  1.46042068e+02, -9.19651985e+00, ...,
#         -8.79406003e-03,  4.65600458e-02,  3.65768619e-03],
#        ...,
#        [-3.04845093e+02,  9.34399414e+01, -7.36051702e+00, ...,
#          1.19021948e-02,  2.90033129e-02, -1.72405767e-02],
#        [-2.38913208e+02,  1.33771118e+02, -3.95286102e+01, ...,
#         -6.29839821e-02,  1.00526687e-02, -5.96400459e-03],
#        [-3.40277710e+02,  1.03581245e+02,  1.59706020e+01, ...,
#         -1.01679217e-03, -5.67695341e-03,  3.54554491e-03]])

# %%
X_train.shape
# Out:
# (648, 193)

# %% [markdown]
# Повторим те же шаги для evaluation части выборки

# %%
def data_preprocessing(path = './vcc2018_evaluation/evaluation') :
    filelist = os.listdir(path)
    df = pd.DataFrame(filelist)
    df = df.rename(columns={0:'file'})
    df['speaker'] = df['file'].apply(lambda x : int(x[0]))
    labels = np.array(df['speaker'])
    df_features = df.apply(extract_features, axis=1)
    data_features_joined = []

    for i in range(0, len(df_features)):
        data_features_joined.append(np.concatenate((
            df_features[i][0],
            df_features[i][1], 
            df_features[i][2], 
            df_features[i][3],
            df_features[i][4]), axis=0))
    
    X = np.array(data_features_joined)
    return X, labels

# %%
data_path = './vcc2018_evaluation/evaluation'
X_eval, labels_eval = data_preprocessing(path=data_path)

# %%
labels_eval
# Out:
# array([4, 0, 5, 1, 0, 7, 7, 2, 7, 5, 0, 6, 6, 3, 0, 4, 0, 4, 4, 2, 2, 3,
#        0, 3, 1, 0, 5, 7, 4, 6, 4, 5, 5, 2, 1, 7, 2, 2, 0, 7, 4, 6, 7, 6,
#        1, 1, 1, 3, 0, 3, 4, 6, 7, 1, 0, 0, 7, 3, 0, 7, 1, 1, 0, 7, 4, 0,
#        6, 5, 0, 2, 6, 5, 1, 1, 0, 0, 2, 4, 4, 1, 6, 7, 3, 5, 1, 1, 5, 0,
#        7, 4, 7, 3, 5, 6, 0, 5, 6, 3, 3, 4, 3, 3, 7, 7, 7, 2, 3, 0, 0, 2,
#        4, 3, 1, 7, 5, 3, 0, 7, 6, 6, 3, 6, 0, 5, 6, 5, 4, 2, 7, 2, 5, 2,
#        3, 6, 6, 5, 3, 4, 5, 6, 7, 4, 1, 1, 6, 1, 2, 6, 1, 4, 1, 6, 3, 0,
#        4, 4, 7, 7, 1, 1, 0, 5, 4, 7, 7, 0, 5, 7, 2, 6, 3, 3, 2, 7, 3, 2,
#        2, 1, 3, 6, 2, 1, 2, 4, 6, 6, 4, 5, 3, 5, 6, 3, 4, 5, 2, 6, 5, 7,
#        0, 1, 5, 1, 2, 2, 3, 4, 2, 5, 1, 4, 2, 6, 3, 4, 1, 6, 6, 3, 3, 5,
#        2, 1, 2, 5, 7, 0, 2, 2, 7, 4, 7, 4, 1, 7, 0, 2, 2, 4, 1, 0, 3, 5,
#        3, 2, 4, 5, 5, 2, 5, 5, 3, 7, 5, 7, 0, 4, 7, 1, 5, 2, 4, 6, 0, 6,
#        3, 4, 6, 0, 1, 0, 4, 3, 6, 1, 6, 2, 5, 1, 3, 0])

# %%
X_eval.shape
# Out:
# (280, 193)

# %% [markdown]
# ## **Модель**

# %%
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

# %% [markdown]
# Создадим простую модель из чередующихся полносвязных линейных слоев и слоев нелинейности ReLU

# %%
import torch.nn.functional as F
from torch.nn import init

input_size = X_train.shape[1]
output_size = len(labels_to_name_mapping)
# ----------------------------
# Audio Classification Model
# ----------------------------
class AudioClassifier2(nn.Module):
    # Еhe model architecture
    def __init__(self):
        super().__init__()
        self.network=nn.Sequential(
            nn.Linear(input_size, 512),
            nn.ReLU(),
            nn.Linear(512, 1024),
            nn.ReLU(),
            nn.Linear(1024, 2048),
            nn.ReLU(),
            nn.Linear(2048,128),
            nn.ReLU(),
            nn.Linear(128, output_size),
            nn.Tanh()
        )
 
    # Forward pass computations
    def forward(self, x):
        return self.network(x)


device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Check that it is on Cuda

# %%
class VCDataset(Dataset):

    def __init__(self, df, y) :
        self.data = df
        self.y = y
    def __len__(self) : 
        return len(self.data)

    def __getitem__(self, idx ):
        return self.data[idx], self.y[idx]

# %%
train_dataset = VCDataset(X_train, labels)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=16, shuffle=True)

# %%
print("Количество батчей на train части = ", len(train_loader))
# Out:
# Количество батчей на train части =  41

# %%
eval_dataset = VCDataset(X_eval, labels_eval)
eval_loader = torch.utils.data.DataLoader(eval_dataset, batch_size=16, shuffle=True)

# %% [markdown]
# ## **Обучение**

# %%
# ----------------------------
# Training Loop
# ----------------------------
def training(model, data_loader, num_epochs):
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(),lr=0.001)
    scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr=0.001,
                                                    steps_per_epoch=int(len(data_loader)),
                                                    epochs=num_epochs,
                                                    anneal_strategy='linear')
    
    for epoch in range(num_epochs):
        running_loss = 0.0
        correct_prediction = 0
        total_prediction = 0

        for i, data in enumerate(data_loader):
            inputs, labels = data[0].to(device), data[1].to(device)
            # Normalize the inputs
            inputs_m, inputs_s = inputs.mean(), inputs.std()
            inputs = (inputs - inputs_m) / inputs_s

            optimizer.zero_grad()

            outputs = model(inputs.float())
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            scheduler.step()

            running_loss += loss.item()

            # Get the predicted class with the highest score
            _, prediction = torch.max(outputs, 1)

            # Count of predictions that matched the target label
            correct_prediction += (prediction == labels).sum().item()
            total_prediction += prediction.shape[0]

        # Print stats at the end of the epoch
        num_batches = len(data_loader)
        avg_loss = running_loss / num_batches
        acc = correct_prediction/total_prediction
        print(f'Epoch: {epoch}, Loss: {avg_loss:.2f}, Accuracy: {acc:.2f}')

    print('Finished Training')

# %%
# Create the model and put it on the GPU if available
model2 = AudioClassifier2()
      inputs = (inputs - inputs_m) / inputs_s

      outputs = model(inputs.float())

      _, prediction = torch.max(outputs, 1)

      correct_prediction += (prediction == labels).sum().item()
      total_prediction += prediction.shape[0]
    
  acc = correct_prediction/total_prediction
  print(f'Accuracy: {acc:.3f}, Total items: {total_prediction}')

# %%
# Run inference on trained model with the validation set
inference(model2, eval_loader)
# Out:
# Accuracy: 1.000, Total items: 280

# %% [markdown]
# #### Даже простая модель показывает хорошие результаты

# %% [markdown]
# ## super resolution (задача 2)
#
# ![im2.jpeg](data:image/jpeg;base64,...)
#
#
# **Цель:**
#
# * Поработать с изображениями
# * Показать умение строить и обучать простые модели
#
# **Условие:**
#
# * Попробовать решить задачу увеличения разрешения входного изображения
#
# * Приветствуется сравнение нейросетевого подхода с классическими методами (линейная, бикубическая интерполяции)
#
#
# **Данные**
#
# В качестве датасета предлагается использовать [data](https://drive.google.com/file/d/1za24UKmQK8L9QVNaVrlMdyx3URTGMpmL/view?usp=sharing)
#
#  В данном датасете ~100 картинок в низком и высоком разрешении
#
# * Для обучения предлагается самостоятельно разбить датасет на **train** (90%) и **validation** (10%)

# %% [markdown]
# ## На подумать (задача 3)
#
# ![im3.jpeg](data:image/jpeg;base64,...)
#
# **Условие - ниже :)**
#
# **Данные**
#
# [data](https://drive.google.com/drive/folders/1_i00deQlwQrNxiv0R8XhmIGtaDGzLbgP?usp=sharing)

# %% [markdown]
# #### Сначала создадим простенькую модельку без смысловой нагрузки

# %%
import torch 
import torch.nn as nn
import numpy as np
from tqdm import tqdm


# create simple model with one conv2d layer

class SimpleModel(nn.Module):
  def __init__(self):
    super(SimpleModel, self).__init__()
    self.conv1 = nn.Conv2d(in_channels=3, out_channels=64, kernel_size=(3, 3))
    self.conv2 = nn.Conv2d(in_channels=64, out_channels=64, kernel_size=(3, 3))
    
    self.act1 = nn.Sigmoid()
    self.act2 = nn.Sigmoid()

  def forward(self, data):
    out = self.conv1(data)
    out = self.act1(out)
    out = self.conv2(out)
    out = self.act2(out)

    return out

# %% [markdown]
# #### создадим инстанс модельки и положим ее на карточку

# %%
# create gpu device
device = torch.device('cuda')

# create model instance
model = SimpleModel()
model = model.to(device)

# %% [markdown]
# #### Так выглядит первый способ получения батча данных

# %%
def get_sample_1():
  data = torch.load("/content/data1.pt")
  
  return data

# %% [markdown]
# #### Прогоним в цикле сетку и измерим время
#
# можно измерить время на втором запуске ячейки после "прогрева" сетки

# %%
# %%time
data = get_sample_1()
print("shape", data.shape)

for i in tqdm(range(150)):
  input = torch.clone(data)
  out = model.forward(input.to(device))

# %% [markdown]
# #### Так выглядит второй способ получения батча данных

# %%
def get_sample_2():
  data = torch.load("/content/data2.pt")
  
  return data

# %% [markdown]
# #### Прогоним в цикле сетку и измерим время

# %%
# %%time

data = get_sample_2()
print("shape", data.shape)

for i in tqdm(range(150)):
  input = torch.clone(data)
  out = model.forward(input.to(device))

# %% [markdown]
# #### Вопрос, почему так отличается скорость ?

# %% [markdown]
# #### Если будут вопросы по условию можно писать мне [tg Dima](https://t.me/DmitryGadecky)
